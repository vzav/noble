# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings("ignore")

# %%
h = pd.read_excel('migration.xlsx', index_col = 0)
h
# Out:
#            Україна  Вінницька  Волинська  Дніпропетровська  Донецька  \
# період
# січ.2018      -245       -244          4               182      -383
# лют.2018      2181       -147        -14               -16      -370
# бер.2018      1689       -162         61               239      -458
# квіт.2018     1867       -218          3               347      -689
# трав.2018     1704       -220        -29              1043     -1185
# черв.2018     1584       -139         34               207      -503
# лип.2018      -855       -465        123              -307      -129
# серп.2018      333       -379        142               652     -1180
# вер.2018       131       -644       -579              -263     -2348
# жовт.2018     -312       -603       -215               128     -1592
# лист.2018     3180       -408       -171               -79      -707
# груд.2018     4912       -213        -46               419      -736
# ...

# %%
h.dtypes
# Out:
# Україна              int64
# Вінницька            int64
# Волинська            int64
# Дніпропетровська     int64
# Донецька             int64
# Житомирська          int64
# Закарпатська         int64
# Запорізька           int64
# Івано-Франківська    int64
# Київська             int64
# Кіровоградська       int64
# Луганська            int64
# Львівська            int64
# Миколаївська         int64
# Одеська              int64
# Полтавська           int64
# Рівненська           int64
# Сумська              int64
# Тернопільська        int64
# Харківська           int64
# Херсонська           int64
# Хмельницька          int64
# Черкаська            int64
# Чернівецька          int64
# Чернігівська         int64
# м.Київ               int64
# dtype: object

# %%
X = h['Вінницька']
X
# Out:
# період
# січ.2018    -244
# лют.2018    -147
# бер.2018    -162
# квіт.2018   -218
# трав.2018   -220
# черв.2018   -139
# лип.2018    -465
# серп.2018   -379
# вер.2018    -644
# жовт.2018   -603
# лист.2018   -408
# груд.2018   -213
# січ.2019    -162
# лют.2019    -254
# Name: Вінницька, dtype: int64
